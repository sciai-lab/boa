# %%
experiment_dict = {}

experiment_dict["benzene"] = {
    "test_paths": [
        "/export/scratch/mklockow/boa/models/test/runs/001_test_benzene_from_10061487",
        "/export/scratch/mklockow/boa/models/test/runs/012_test_benzene_from_10061488",
        "/export/scratch/mklockow/boa/models/test/runs/015_test_benzene_from_10061489",
    ],
}

experiment_dict["ethane"] = {
    "test_paths": [
        "/export/scratch/mklockow/boa/models/test/runs/003_test_ethane_from_10061484",
        "/export/scratch/mklockow/boa/models/test/runs/013_test_ethane_from_10061485",
        "/export/scratch/mklockow/boa/models/test/runs/014_test_ethane_from_10061486",
    ],
}
experiment_dict["ethanol"] = {
    "test_paths": [
        "/export/scratch/mklockow/boa/models/test/runs/005_test_ethanol_from_10061481",
        "/export/scratch/mklockow/boa/models/test/runs/016_test_ethanol_from_10061482",
        "/export/scratch/mklockow/boa/models/test/runs/019_test_ethanol_from_10061483",
    ],
}
experiment_dict["malonaldehyde"] = {
    "test_paths": [
        "/export/scratch/mklockow/boa/models/test/runs/011_test_malonaldehyde_from_10061478",
        "/export/scratch/mklockow/boa/models/test/runs/022_test_malonaldehyde_from_10061479",
        "/export/scratch/mklockow/boa/models/test/runs/023_test_malonaldehyde_from_10061480",
    ],
}
experiment_dict["phenol"] = {
    "test_paths": [
        "/export/scratch/mklockow/boa/models/test/runs/009_test_phenol_from_10061472",
        "/export/scratch/mklockow/boa/models/test/runs/018_test_phenol_from_10061476",
        "/export/scratch/mklockow/boa/models/test/runs/021_test_phenol_from_10061477",
    ],
}
experiment_dict["resorcinol"] = {
    "test_paths": [
        "/export/scratch/mklockow/boa/models/test/runs/007_test_resorcinol_from_10061468",
        "/export/scratch/mklockow/boa/models/test/runs/017_test_resorcinol_from_10061469",
        "/export/scratch/mklockow/boa/models/test/runs/020_test_resorcinol_from_10061471",
    ],
}
experiment_dict["qm9_vasp_small"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/039_test_qm9_vasp_small_from_437', '/export/scratch/mklockow/boa/models/test/runs/053_test_qm9_vasp_small_from_431', '/export/scratch/mklockow/boa/models/test/runs/057_test_qm9_vasp_small_from_430'],
}
experiment_dict["qm9_vasp_noabs"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/041_test_qm9_vasp_small_noabs_from_454', '/export/scratch/mklockow/boa/models/test/runs/052_test_qm9_vasp_small_noabs_from_433', '/export/scratch/mklockow/boa/models/test/runs/058_test_qm9_vasp_small_noabs_from_434'],
}
experiment_dict["qm9_vasp_noradcor"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/043_test_qm9_vasp_small_noradcor_from_453', '/export/scratch/mklockow/boa/models/test/runs/048_test_qm9_vasp_small_noradcor_from_429', '/export/scratch/mklockow/boa/models/test/runs/054_test_qm9_vasp_small_noradcor_from_432']
}
experiment_dict["qm9_vasp_noabs_noradcor"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/045_test_qm9_vasp_small_noabs_noradcor_from_456', '/export/scratch/mklockow/boa/models/test/runs/049_test_qm9_vasp_small_noabs_noradcor_from_444', '/export/scratch/mklockow/boa/models/test/runs/055_test_qm9_vasp_small_noabs_noradcor_from_446'],
}
experiment_dict["qm9_vasp_large"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/070_test_qm9_vasp_from_463', '/export/scratch/mklockow/boa/models/test/runs/071_test_qm9_vasp_from_438', '/export/scratch/mklockow/boa/models/test/runs/074_test_qm9_vasp_from_440', '/export/scratch/mklockow/boa/models/test/runs/194_test_qm9_vasp__max_n_probe_per_pass-20000_from_527']
}
experiment_dict["qm9_pyscf_small"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/066_test_qm9_pyscf_small_from_491', '/export/scratch/mklockow/boa/models/test/runs/073_test_qm9_pyscf_small_from_492', '/export/scratch/mklockow/boa/models/test/runs/075_test_qm9_pyscf_small_from_493']
}
experiment_dict["qm9_pyscf_large"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/068_test_qm9_pyscf_from_484', '/export/scratch/mklockow/boa/models/test/runs/072_test_qm9_pyscf_from_485', '/export/scratch/mklockow/boa/models/test/runs/076_test_qm9_pyscf_from_487', '/export/scratch/mklockow/boa/models/test/runs/181_test_qm9_pyscf_from_528', '/export/scratch/mklockow/boa/models/test/runs/265_test_qm9_pyscf__max_n_probe_per_pass-30000_from_541']
}
experiment_dict["qm9_vasp_small_small_basis"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/158_test_qm9_vasp_small_small_basis_from_494', '/export/scratch/mklockow/boa/models/test/runs/177_test_qm9_vasp_small_small_basis_from_495', '/export/scratch/mklockow/boa/models/test/runs/178_test_qm9_vasp_small_small_basis_from_496']
}
experiment_dict["qm9_vasp_small_medium_basis"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/240_test_qm9_vasp_small_medium_basis_from_537', '/export/scratch/mklockow/boa/models/test/runs/241_test_qm9_vasp_small_medium_basis_from_538', '/export/scratch/mklockow/boa/models/test/runs/267_test_qm9_vasp_small_medium_basis__max_n_probe_per_pass-90000_from_540']
}
experiment_dict["qm9_vasp_small_large_cutoff"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/160_test_qm9_vasp_small_large_cutoff__max_n_probe_per_pass-10000_from_503', '/export/scratch/mklockow/boa/models/test/runs/179_test_qm9_vasp_small_large_cutoff__max_n_probe_per_pass-10000_from_504', '/export/scratch/mklockow/boa/models/test/runs/182_test_qm9_vasp_small_large_cutoff__max_n_probe_per_pass-10000_from_505']
}
experiment_dict["qm9_vasp_small_linear_basis"] = {
    "test_paths": ['/export/scratch/mklockow/boa/models/test/runs/192_test_qm9_vasp_small_linear_basis_from_513', '/export/scratch/mklockow/boa/models/test/runs/195_test_qm9_vasp_small_linear_basis_from_514', '/export/scratch/mklockow/boa/models/test/runs/196_test_qm9_vasp_small_linear_basis_from_515']
}

# %%
# for each experiment in experiment_dict, load the 
from pathlib import Path

import numpy as np
import torch


for experiment, params in experiment_dict.items():
    print(f"Experiment: {experiment}")
    experiment_dict[experiment]["nmapes"] = []
    for test_path in params["test_paths"]:
        nmape_path = Path(test_path) / "tensorboard/version_0/nmape_test.pt"
        if nmape_path.exists():
            nmape = np.array(torch.load(open(nmape_path, "rb")))
            experiment_dict[experiment]["nmapes"].append(nmape)
            print(f"  Test path: {test_path}, NMAPE: {np.mean(nmape):.4f} ± {np.std(nmape):.4f}")
# Out:
# Experiment: benzene
#   Test path: /export/scratch/mklockow/boa/models/test/runs/001_test_benzene_from_10061487, NMAPE: 0.3550 ± 0.0163
#   Test path: /export/scratch/mklockow/boa/models/test/runs/012_test_benzene_from_10061488, NMAPE: 0.3614 ± 0.0167
#   Test path: /export/scratch/mklockow/boa/models/test/runs/015_test_benzene_from_10061489, NMAPE: 0.3666 ± 0.0177
# Experiment: ethane
#   Test path: /export/scratch/mklockow/boa/models/test/runs/003_test_ethane_from_10061484, NMAPE: 0.7667 ± 0.0323
#   Test path: /export/scratch/mklockow/boa/models/test/runs/013_test_ethane_from_10061485, NMAPE: 0.7759 ± 0.0323
#   Test path: /export/scratch/mklockow/boa/models/test/runs/014_test_ethane_from_10061486, NMAPE: 0.7726 ± 0.0350
# Experiment: ethanol
#   Test path: /export/scratch/mklockow/boa/models/test/runs/005_test_ethanol_from_10061481, NMAPE: 0.7045 ± 0.0303
#   Test path: /export/scratch/mklockow/boa/models/test/runs/016_test_ethanol_from_10061482, NMAPE: 0.7050 ± 0.0316
# ...

# %%
# for each experiment calculate the mean and std of the means of the nmapes
for experiment, params in experiment_dict.items():
    nmapes = params["nmapes"]
    mean_nmapes = [np.mean(nmape) for nmape in nmapes]
    # standard error of the mean
    sem_nmapes = np.std(mean_nmapes) / np.sqrt(len(mean_nmapes))
    print(f"Experiment: {experiment}, Mean NMAPE: {np.mean(mean_nmapes):.5f} ± {sem_nmapes:.5}")
# Out:
# Experiment: benzene, Mean NMAPE: 0.36098 ± 0.0027542
# Experiment: ethane, Mean NMAPE: 0.77174 ± 0.0021944
# Experiment: ethanol, Mean NMAPE: 0.70963 ± 0.0039628
# Experiment: malonaldehyde, Mean NMAPE: 0.61172 ± 0.011052
# Experiment: phenol, Mean NMAPE: 0.56291 ± 0.033595
# Experiment: resorcinol, Mean NMAPE: 0.37083 ± 0.0039356
# Experiment: qm9_vasp_small, Mean NMAPE: 0.13814 ± 0.00033772
# Experiment: qm9_vasp_noabs, Mean NMAPE: 0.14231 ± 0.0005648
# Experiment: qm9_vasp_noradcor, Mean NMAPE: 0.16744 ± 0.0035962
# Experiment: qm9_vasp_noabs_noradcor, Mean NMAPE: 0.20380 ± 0.0019766
# Experiment: qm9_vasp_large, Mean NMAPE: 0.13360 ± 0.00054493
# Experiment: qm9_pyscf_small, Mean NMAPE: 0.12619 ± 0.0096809
# Experiment: qm9_pyscf_large, Mean NMAPE: 0.11582 ± 0.0060371
# Experiment: qm9_vasp_small_small_basis, Mean NMAPE: 0.19363 ± 0.0011262
# Experiment: qm9_vasp_small_medium_basis, Mean NMAPE: 0.15039 ± 0.0002726
# ...

# %%
# for each experiment calculate the median and mean and std of medians of the nmapes
for experiment, params in experiment_dict.items():
    nmapes = params["nmapes"]
    median_nmapes = [np.median(nmape) for nmape in nmapes]
    # standard error of the median
    sem_median_nmapes = np.std(median_nmapes) / np.sqrt(len(median_nmapes))
    print(f"Experiment: {experiment}, Median NMAPE: {np.mean(median_nmapes):.4f} ± {sem_median_nmapes:.4}")
# Out:
# Experiment: benzene, Median NMAPE: 0.3590 ± 0.00271
# Experiment: ethane, Median NMAPE: 0.7700 ± 0.002357
# Experiment: ethanol, Median NMAPE: 0.7083 ± 0.003977
# Experiment: malonaldehyde, Median NMAPE: 0.6072 ± 0.01034
# Experiment: phenol, Median NMAPE: 0.4763 ± 0.006252
# Experiment: resorcinol, Median NMAPE: 0.3703 ± 0.003963
# Experiment: qm9_vasp_small, Median NMAPE: 0.1319 ± 0.0002264
# Experiment: qm9_vasp_noabs, Median NMAPE: 0.1360 ± 0.0002702
# Experiment: qm9_vasp_noradcor, Median NMAPE: 0.1367 ± 0.0007703
# Experiment: qm9_vasp_noabs_noradcor, Median NMAPE: 0.1748 ± 0.001859
# Experiment: qm9_vasp_large, Median NMAPE: 0.1274 ± 0.0006244
# Experiment: qm9_pyscf_small, Median NMAPE: 0.1011 ± 0.000284
# Experiment: qm9_pyscf_large, Median NMAPE: 0.0968 ± 0.0002211
# Experiment: qm9_vasp_small_small_basis, Median NMAPE: 0.1862 ± 0.00108
# Experiment: qm9_vasp_small_medium_basis, Median NMAPE: 0.1444 ± 0.00027
# ...

# %%
import matplotlib.pyplot as plt

params = experiment_dict["qm9_pyscf_large"]
nmapes = params["nmapes"]
plt.figure(figsize=(8, 6))
plt.hist(nmapes[1], bins=20, alpha=0.5, label="qm9_pyscf_large")
plt.xlabel("NMAPE")
plt.ylabel("Frequency")
plt.title(f"NMAPE Distribution for qm9_pyscf_large")
plt.legend()
plt.yscale("log")
plt.grid()
plt.show()

# %%
# Plot a histogram of the nmapes for each experiment
for experiment, params in experiment_dict.items():
    nmapes = params["nmapes"]
    plt.figure(figsize=(8, 6))
    for i, nmape in enumerate(nmapes):
        plt.hist(nmape, bins=30, alpha=0.5, label=f"Test {i+1}")
    plt.xlabel("NMAPE")
    plt.ylabel("Frequency")
    plt.title(f"NMAPE Distribution for {experiment}")
    plt.legend()
    plt.grid()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

for experiment, params in experiment_dict.items():
    nmapes = params["nmapes"]
    all_nmape = np.concatenate(nmapes)
    # Remove extreme outliers for visualization (e.g., clip to 99th percentile)
    lower, upper = np.percentile(all_nmape, [1, 99])
    clipped_nmape = all_nmape[(all_nmape >= lower) & (all_nmape <= upper)]

    plt.figure(figsize=(8, 6))
    plt.hist(clipped_nmape, bins=30, alpha=0.7, color='tab:blue')
    plt.xlabel("NMAPE")
    plt.ylabel("Frequency")
    plt.title(f"NMAPE Distribution for {experiment} (1st-99th percentile)")
    plt.grid()
    plt.show()

    # Optionally, also show a boxplot for a summary
    plt.figure(figsize=(6, 2))
    plt.boxplot(clipped_nmape, vert=False, showfliers=False)
    plt.xlabel("NMAPE")
    plt.title(f"NMAPE Boxplot for {experiment} (no outliers)")
    plt.grid(axis='x')
    plt.show()
