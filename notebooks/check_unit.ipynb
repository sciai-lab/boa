# %%
import pyscf

# water geometry
mol = pyscf.gto.Mole()
mol.atom = '''
O  0.0000000  0.0000000  0.0000000
H  0.0000000 -0.7570000  0.5870000
H  0.0000000  0.7570000  0.5870000
'''
mol.basis = 'sto-3g'
mol.build()

# %%
print(mol._atom)
print(mol._basis)
# Out:
# [('O', [0.0, 0.0, 0.0]), ('H', [0.0, -1.430522676295752, 1.1092692351196913]), ('H', [0.0, 1.430522676295752, 1.1092692351196913])]
# {'H': [[0, [3.42525091, 0.15432897], [0.62391373, 0.53532814], [0.1688554, 0.44463454]]], 'O': [[0, [130.70932, 0.15432897], [23.808861, 0.53532814], [6.4436083, 0.44463454]], [0, [5.0331513, -0.09996723], [1.1695961, 0.39951283], [0.380389, 0.70011547]], [1, [5.0331513, 0.15591627], [1.1695961, 0.60768372], [0.380389, 0.39195739]]]}
