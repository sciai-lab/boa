# %%
import pyscf
from pathlib import Path
from mldft.utils.draw_molecule import load_molecule, draw_molecule
from IPython.display import SVG, display

# %%
for file in Path("/export/scratch/ialgroup/dft_data/QMUGS/xyzs").glob("*.xyz"):
    mol = load_molecule(file)
    svg = draw_molecule(mol, width=300, height=300)
    display(SVG(svg))
